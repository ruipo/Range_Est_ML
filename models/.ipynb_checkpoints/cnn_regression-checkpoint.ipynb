# %%
import keras
import h5py
import numpy as np
import pandas as pd
import seaborn as sn
import time
import matplotlib.pyplot as plt

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

class traininghist(keras.callbacks.Callback):
    def __init__(self, test_data):
        self.test_data = test_data
        self.trainingloss = []
        self.trainingmape = []
        
    def on_epoch_end(self, epoch, logs={}):
        x, y = self.test_data
        loss, mape = self.model.evaluate(x, y, verbose=0)
        self.trainingloss.append(loss)
        self.trainingmape.append(mape)
        print('Training loss: {}, mape: {}\n'.format(loss, mape))
# Out:
# Using TensorFlow backend.

# %%
#Import training data

features = np.loadtxt('vec_mat_features_icex_src_0.01train_norm.csv',delimiter=",")
labels_unstand = np.loadtxt('vec_mat_rlabels_icex_src_0.01train.csv',delimiter=",")
labels_t = []

real = features[:,0::2]
imag = features[:,1::2]
X_train = np.zeros((features.shape[0],32,32,2))

for k in range(features.shape[0]):
    count = 0
    for i in range(32):
        for j in range(i,32):
            X_train[k,i,j,0] = real[k,count]
            X_train[k,i,j,1] = imag[k,count]
            
            if i!=j:
                X_train[k,j,i,0] = X_train[k,i,j,0]
                X_train[k,j,i,1] = -X_train[k,i,j,1]
                
            count = count + 1
    
    #X_train[k,:,:,0] = X_train[k,:,:,0]/np.amax(np.abs(X_train[k,:,:,0]))
    #X_train[k,:,:,1] = X_train[k,:,:,1]/np.amax(np.abs(X_train[k,:,:,1]))        

labels_unstand = labels_unstand.ravel()
#y_train,mu,sigma_labels = std_y(labels_unstand)

y_train = labels_unstand

# %%
#Import test data

features_test = np.loadtxt('vec_mat_features_icex_src_test2_norm.csv',delimiter=",")
temp_ytest = np.loadtxt('vec_mat_rlabels_icex_src_test2.csv',delimiter=",")
y_test= []

real_test = features_test[:,0::2]
imag_test = features_test[:,1::2]
X_test = np.zeros((features_test.shape[0],32,32,2))

for k in range(features_test.shape[0]):
    count = 0
    for i in range(32):
        for j in range(i,32):
            X_test[k,i,j,0] = real_test[k,count]
            X_test[k,i,j,1] = imag_test[k,count]
            
            if i!=j:
                X_test[k,j,i,0] = X_test[k,i,j,0]
                X_test[k,j,i,1] = -X_test[k,i,j,1]
                
            count = count + 1
    
    #X_test[k,:,:,0] = X_test[k,:,:,0]/np.amax(np.abs(X_test[k,:,:,0]))
    #X_test[k,:,:,1] = X_test[k,:,:,1]/np.amax(np.abs(X_test[k,:,:,1])) 

temp_ytest = temp_ytest.ravel()
#y_test = (temp_ytest - mu)/sigma_labels
y_test = temp_ytest


print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (4701, 32, 32, 2)
# (4701,)
# (1000, 32, 32, 2)
# (1000,)

# %%
#Training

index=np.arange(X_train.shape[0])
np.random.shuffle(index)

X_train=X_train[index,:,:,:]
y_train=y_train[index]

drate = 0.25
n_node = 256
batch_size = 128
loss='mean_squared_error'

model = keras.Sequential([
    #keras.layers.Conv2D(input_shape=(32,32,2), filters=8, kernel_size=5,padding='same',activation='selu'),
    #keras.layers.Dropout(0.5),
    #keras.layers.BatchNormalization(),
    keras.layers.Conv2D(input_shape=(32,32,2),filters=8, kernel_size=7,padding='same',activation='selu',strides=(2,2)),
    keras.layers.BatchNormalization(),
    #keras.layers.Dropout(0.5),
    keras.layers.Conv2D(filters=16, kernel_size=5,padding='same',activation='selu',strides=(2,2)),
    keras.layers.BatchNormalization(),
    #keras.layers.Dropout(0.5),
    keras.layers.Conv2D(filters=32, kernel_size=3,padding='same',activation='selu',strides=(2,2)),
    keras.layers.BatchNormalization(),
    #keras.layers.Dropout(0.5),
    #keras.layers.Conv2D(filters=128, kernel_size=3,padding='same',activation='selu',strides=(2,2)),
    #keras.layers.BatchNormalization(),
    keras.layers.Flatten(),
    keras.layers.Dense(units=n_node, activation='sigmoid'),
    keras.layers.Dropout(drate),
    keras.layers.Dense(units=1, activation='linear')])

lr = 0.001
optimizer = keras.optimizers.Adam(lr)

model.compile(optimizer,loss, metrics=['mape'])

filepath = "temp.h5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', save_best_only=True, mode='auto',period=1)
reduce = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=25, mode='auto')
early = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=1e-4, patience=50, mode='auto',restore_best_weights=True)
traininghistory = traininghist((X_train,y_train))
callbacks_list = [checkpoint,reduce,traininghistory,early]

infdb = model.fit(X_train, y_train, batch_size,verbose = True, epochs=2000, validation_split=0.2, shuffle=True,callbacks=callbacks_list)

#Testing

test_loss, test_acc = model.evaluate(X_test,y_test)
train_loss, train_acc = model.evaluate(X_train,y_train)
    
predictions = model.predict(X_test)
diff = abs((np.transpose(predictions))-(y_test))
error = diff[diff>1]
percent_correct = (len(y_test)-len(error))/len(y_test)
    
predictions_train = model.predict(X_train)
diff = abs((np.transpose(predictions_train))-(y_train))
error = diff[diff>1]
percent_correct_train = (len(y_train)-len(error))/len(y_train)
    
print('Training mape:', train_acc)
print('Test mape:', test_acc)
print('Training percent within 1km:',percent_correct_train*100)
print('Testing percent within 1km:', percent_correct*100)
# Out:
# Train on 3760 samples, validate on 941 samples
# Epoch 1/2000
# 3760/3760 [==============================] - 4s 1ms/step - loss: 552.8532 - mean_absolute_percentage_error: 70.7490 - val_loss: 367.8143 - val_mean_absolute_percentage_error: 59.4918
# Training loss: 373.92729250955165, mape: 60.74743456780669
#
# Epoch 2/2000
# 3760/3760 [==============================] - 1s 377us/step - loss: 334.2052 - mean_absolute_percentage_error: 62.3462 - val_loss: 285.2452 - val_mean_absolute_percentage_error: 61.4029
# Training loss: 290.7000462755805, mape: 63.11945919157773
#
# Epoch 3/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 266.1368 - mean_absolute_percentage_error: 65.5839 - val_loss: 234.6241 - val_mean_absolute_percentage_error: 65.6996
# Training loss: 239.10168896520727, mape: 67.62488879845057
#
# Epoch 4/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 225.6270 - mean_absolute_percentage_error: 70.4985 - val_loss: 206.3644 - val_mean_absolute_percentage_error: 70.3173
# Training loss: 210.14091573819482, mape: 72.57284843219237
#
# Epoch 5/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 203.1707 - mean_absolute_percentage_error: 75.0097 - val_loss: 192.2510 - val_mean_absolute_percentage_error: 74.5203
# Training loss: 195.557509041928, mape: 76.91229732653811
#
# Epoch 6/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 193.9361 - mean_absolute_percentage_error: 79.5510 - val_loss: 185.4582 - val_mean_absolute_percentage_error: 78.0869
# Training loss: 188.09447889687075, mape: 80.42989394482692
#
# Epoch 7/2000
# 3760/3760 [==============================] - 1s 375us/step - loss: 187.4906 - mean_absolute_percentage_error: 82.0115 - val_loss: 181.0196 - val_mean_absolute_percentage_error: 79.3563
# Training loss: 183.0239083120301, mape: 81.50149379033176
#
# Epoch 8/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 165.2891 - mean_absolute_percentage_error: 65.9964 - val_loss: 135.8203 - val_mean_absolute_percentage_error: 53.0092
# Training loss: 137.4610054748055, mape: 53.607102430417065
#
# Epoch 9/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 124.9732 - mean_absolute_percentage_error: 47.2954 - val_loss: 103.7963 - val_mean_absolute_percentage_error: 40.9339
# Training loss: 104.75296493105066, mape: 41.5571277263798
#
# Epoch 10/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 96.3109 - mean_absolute_percentage_error: 38.4251 - val_loss: 86.5703 - val_mean_absolute_percentage_error: 32.4216
# Training loss: 88.21049161942253, mape: 31.89410105666514
#
# Epoch 11/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 76.8121 - mean_absolute_percentage_error: 34.2206 - val_loss: 74.7668 - val_mean_absolute_percentage_error: 26.6399
# Training loss: 75.69249354989142, mape: 26.010367990934807
#
# Epoch 12/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 63.4191 - mean_absolute_percentage_error: 29.7936 - val_loss: 57.0495 - val_mean_absolute_percentage_error: 27.7507
# Training loss: 55.9693454838996, mape: 27.006591658114473
#
# Epoch 13/2000
# 3760/3760 [==============================] - 1s 365us/step - loss: 54.5858 - mean_absolute_percentage_error: 28.0841 - val_loss: 55.5575 - val_mean_absolute_percentage_error: 24.3230
# Training loss: 54.01180109585176, mape: 23.40379810880991
#
# Epoch 14/2000
# 3760/3760 [==============================] - 1s 381us/step - loss: 47.9556 - mean_absolute_percentage_error: 26.0747 - val_loss: 51.8707 - val_mean_absolute_percentage_error: 23.1028
# Training loss: 48.24973915617812, mape: 21.51284959797554
#
# Epoch 15/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 45.0997 - mean_absolute_percentage_error: 25.1574 - val_loss: 43.3879 - val_mean_absolute_percentage_error: 25.5104
# Training loss: 40.800378344612305, mape: 23.938559354657546
#
# Epoch 16/2000
# 3760/3760 [==============================] - 1s 364us/step - loss: 41.0394 - mean_absolute_percentage_error: 23.8613 - val_loss: 41.8148 - val_mean_absolute_percentage_error: 26.6879
# Training loss: 37.70891637098178, mape: 24.62231089890802
#
# Epoch 17/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 36.5924 - mean_absolute_percentage_error: 22.1166 - val_loss: 38.8034 - val_mean_absolute_percentage_error: 25.9418
# Training loss: 35.13032449293431, mape: 24.213203964931257
#
# Epoch 18/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 33.3843 - mean_absolute_percentage_error: 20.4590 - val_loss: 34.2161 - val_mean_absolute_percentage_error: 19.5233
# Training loss: 30.78232458504533, mape: 17.790757540970805
#
# Epoch 19/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 29.8842 - mean_absolute_percentage_error: 19.5213 - val_loss: 31.0048 - val_mean_absolute_percentage_error: 19.7186
# Training loss: 26.894248354615012, mape: 17.841160648251005
#
# Epoch 20/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 27.4413 - mean_absolute_percentage_error: 18.7679 - val_loss: 28.1813 - val_mean_absolute_percentage_error: 19.8510
# Training loss: 24.004732190789223, mape: 17.56533599898958
#
# Epoch 21/2000
# 3760/3760 [==============================] - 1s 377us/step - loss: 26.0193 - mean_absolute_percentage_error: 18.5614 - val_loss: 29.9882 - val_mean_absolute_percentage_error: 16.5466
# Training loss: 25.199447794940415, mape: 14.571274819665197
#
# Epoch 22/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 22.7765 - mean_absolute_percentage_error: 17.2879 - val_loss: 26.0684 - val_mean_absolute_percentage_error: 16.2480
# Training loss: 21.485366185911918, mape: 14.14199658044727
#
# Epoch 23/2000
# 3760/3760 [==============================] - 1s 364us/step - loss: 21.0244 - mean_absolute_percentage_error: 16.7089 - val_loss: 22.5758 - val_mean_absolute_percentage_error: 18.3546
# Training loss: 17.89223499862064, mape: 16.018915976090423
#
# Epoch 24/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 19.3299 - mean_absolute_percentage_error: 15.9527 - val_loss: 21.2219 - val_mean_absolute_percentage_error: 17.7788
# Training loss: 17.087876500639098, mape: 15.396109819767247
#
# Epoch 25/2000
# 3760/3760 [==============================] - 1s 365us/step - loss: 17.8885 - mean_absolute_percentage_error: 15.4698 - val_loss: 20.4366 - val_mean_absolute_percentage_error: 15.0894
# Training loss: 15.739142309374262, mape: 12.728041917662548
#
# Epoch 26/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 17.0690 - mean_absolute_percentage_error: 15.5876 - val_loss: 19.8142 - val_mean_absolute_percentage_error: 15.9562
# Training loss: 14.9172890514446, mape: 13.517478044579269
#
# Epoch 27/2000
# 3760/3760 [==============================] - 1s 375us/step - loss: 16.6335 - mean_absolute_percentage_error: 14.9612 - val_loss: 18.9260 - val_mean_absolute_percentage_error: 15.4367
# Training loss: 13.676830066972224, mape: 12.785062120052581
#
# Epoch 28/2000
# 3760/3760 [==============================] - 1s 366us/step - loss: 15.2101 - mean_absolute_percentage_error: 14.4143 - val_loss: 25.3050 - val_mean_absolute_percentage_error: 14.1716
# Training loss: 18.627854394091113, mape: 11.928062632093528
#
# Epoch 29/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 14.5028 - mean_absolute_percentage_error: 14.2189 - val_loss: 17.5606 - val_mean_absolute_percentage_error: 14.7033
# Training loss: 11.869881798525714, mape: 12.172731864099882
#
# Epoch 30/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 13.3537 - mean_absolute_percentage_error: 13.7237 - val_loss: 22.3184 - val_mean_absolute_percentage_error: 14.0158
# Training loss: 16.062408175424828, mape: 11.579570973129938
#
# Epoch 31/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 12.8484 - mean_absolute_percentage_error: 13.3718 - val_loss: 15.7786 - val_mean_absolute_percentage_error: 16.1484
# Training loss: 10.496976502269817, mape: 13.417276274115704
#
# Epoch 32/2000
# 3760/3760 [==============================] - 1s 366us/step - loss: 12.1961 - mean_absolute_percentage_error: 13.2852 - val_loss: 15.7156 - val_mean_absolute_percentage_error: 13.5378
# Training loss: 9.92792097869464, mape: 10.793085742975595
#
# Epoch 33/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 11.2562 - mean_absolute_percentage_error: 12.8003 - val_loss: 15.1389 - val_mean_absolute_percentage_error: 13.9548
# Training loss: 9.385415025478574, mape: 11.119492757830105
#
# Epoch 34/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 11.1795 - mean_absolute_percentage_error: 13.0803 - val_loss: 15.5776 - val_mean_absolute_percentage_error: 13.5641
# Training loss: 9.532357417733282, mape: 10.84654922663874
#
# Epoch 35/2000
# 3760/3760 [==============================] - 1s 379us/step - loss: 10.8954 - mean_absolute_percentage_error: 12.6564 - val_loss: 13.5423 - val_mean_absolute_percentage_error: 13.0687
# Training loss: 7.982868807236201, mape: 10.156718660024755
#
# Epoch 36/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 10.1786 - mean_absolute_percentage_error: 12.2124 - val_loss: 20.1485 - val_mean_absolute_percentage_error: 12.7875
# Training loss: 12.935453364606158, mape: 9.996894658714933
#
# Epoch 37/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 9.8243 - mean_absolute_percentage_error: 12.0472 - val_loss: 17.3390 - val_mean_absolute_percentage_error: 12.4076
# Training loss: 10.674425570210659, mape: 9.552135026092301
#
# Epoch 38/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 9.2038 - mean_absolute_percentage_error: 11.6536 - val_loss: 15.9555 - val_mean_absolute_percentage_error: 12.2759
# Training loss: 9.05673176510439, mape: 9.312410612254416
#
# Epoch 39/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 8.7943 - mean_absolute_percentage_error: 11.7331 - val_loss: 16.9216 - val_mean_absolute_percentage_error: 12.6409
# Training loss: 9.613090161743683, mape: 9.478182590000175
#
# Epoch 40/2000
# 3760/3760 [==============================] - 1s 364us/step - loss: 9.0576 - mean_absolute_percentage_error: 11.6998 - val_loss: 13.0369 - val_mean_absolute_percentage_error: 11.9796
# Training loss: 6.979409287417602, mape: 8.987216405781298
#
# Epoch 41/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 8.8399 - mean_absolute_percentage_error: 12.0449 - val_loss: 12.4536 - val_mean_absolute_percentage_error: 13.7374
# Training loss: 6.439755017593601, mape: 9.964230157446035
#
# Epoch 42/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 8.2495 - mean_absolute_percentage_error: 11.2968 - val_loss: 11.8863 - val_mean_absolute_percentage_error: 12.9620
# Training loss: 5.9202543659125, mape: 9.382343280875817
#
# Epoch 43/2000
# 3760/3760 [==============================] - 1s 377us/step - loss: 7.7082 - mean_absolute_percentage_error: 11.1384 - val_loss: 12.3710 - val_mean_absolute_percentage_error: 11.9843
# Training loss: 6.288151885671479, mape: 8.726826272399292
#
# Epoch 44/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 7.8753 - mean_absolute_percentage_error: 11.2731 - val_loss: 14.5316 - val_mean_absolute_percentage_error: 11.6988
# Training loss: 8.050961543336571, mape: 8.668024015639645
#
# Epoch 45/2000
# 3760/3760 [==============================] - 1s 383us/step - loss: 7.5780 - mean_absolute_percentage_error: 11.1105 - val_loss: 10.8949 - val_mean_absolute_percentage_error: 12.2621
# Training loss: 5.159689217368432, mape: 8.622968484228963
#
# Epoch 46/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 7.1334 - mean_absolute_percentage_error: 10.4853 - val_loss: 11.8854 - val_mean_absolute_percentage_error: 13.4680
# Training loss: 5.585204904471476, mape: 9.556154688884035
#
# Epoch 47/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 7.1373 - mean_absolute_percentage_error: 10.7669 - val_loss: 11.9626 - val_mean_absolute_percentage_error: 11.1665
# Training loss: 5.639626243524768, mape: 7.8305310247502815
#
# Epoch 48/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 7.0259 - mean_absolute_percentage_error: 10.5759 - val_loss: 11.1175 - val_mean_absolute_percentage_error: 10.9788
# Training loss: 5.160519124598889, mape: 7.572051206717362
#
# Epoch 49/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 7.0454 - mean_absolute_percentage_error: 10.7483 - val_loss: 11.1163 - val_mean_absolute_percentage_error: 11.2332
# Training loss: 5.050342905904303, mape: 7.764993440798054
#
# Epoch 50/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 6.5356 - mean_absolute_percentage_error: 10.2889 - val_loss: 11.8240 - val_mean_absolute_percentage_error: 10.9567
# Training loss: 5.783499478938808, mape: 7.7599006446719905
#
# Epoch 51/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 6.7890 - mean_absolute_percentage_error: 10.5379 - val_loss: 14.0452 - val_mean_absolute_percentage_error: 15.6176
# Training loss: 6.654894244744407, mape: 10.936761005257981
#
# Epoch 52/2000
# 3760/3760 [==============================] - 1s 362us/step - loss: 6.5009 - mean_absolute_percentage_error: 10.1872 - val_loss: 11.9348 - val_mean_absolute_percentage_error: 10.5588
# Training loss: 5.748245026653966, mape: 7.528998111415685
#
# Epoch 53/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 6.2550 - mean_absolute_percentage_error: 10.2450 - val_loss: 10.8050 - val_mean_absolute_percentage_error: 11.1017
# Training loss: 4.468579848759531, mape: 7.347461564113322
#
# Epoch 54/2000
# 3760/3760 [==============================] - 1s 361us/step - loss: 6.1091 - mean_absolute_percentage_error: 10.2529 - val_loss: 10.0391 - val_mean_absolute_percentage_error: 11.0597
# Training loss: 4.119811897707908, mape: 7.173315271776398
#
# Epoch 55/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 5.9464 - mean_absolute_percentage_error: 9.7561 - val_loss: 9.4981 - val_mean_absolute_percentage_error: 11.5187
# Training loss: 3.9410007998578678, mape: 7.488750683350959
#
# Epoch 56/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 6.1194 - mean_absolute_percentage_error: 10.0255 - val_loss: 10.2430 - val_mean_absolute_percentage_error: 11.6443
# Training loss: 4.134139497745192, mape: 7.589192170331996
#
# Epoch 57/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 5.9005 - mean_absolute_percentage_error: 10.0231 - val_loss: 10.6415 - val_mean_absolute_percentage_error: 10.5431
# Training loss: 4.47464039974379, mape: 6.9183050121963845
#
# Epoch 58/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 5.6459 - mean_absolute_percentage_error: 9.4827 - val_loss: 9.7477 - val_mean_absolute_percentage_error: 10.7651
# Training loss: 3.998961943865989, mape: 6.856450776094276
#
# Epoch 59/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 5.8359 - mean_absolute_percentage_error: 9.7859 - val_loss: 11.3471 - val_mean_absolute_percentage_error: 13.8345
# Training loss: 4.675876395090213, mape: 9.482361063808108
#
# Epoch 60/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 5.8069 - mean_absolute_percentage_error: 9.5877 - val_loss: 10.8261 - val_mean_absolute_percentage_error: 10.6574
# Training loss: 4.261695335987045, mape: 6.909026956791524
#
# Epoch 61/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 5.5812 - mean_absolute_percentage_error: 9.5270 - val_loss: 14.6333 - val_mean_absolute_percentage_error: 10.9873
# Training loss: 7.370575439673844, mape: 7.751985839214053
#
# Epoch 62/2000
# 3760/3760 [==============================] - 1s 378us/step - loss: 5.6119 - mean_absolute_percentage_error: 9.5509 - val_loss: 10.3434 - val_mean_absolute_percentage_error: 12.2335
# Training loss: 4.003320674494565, mape: 7.705423792076476
#
# Epoch 63/2000
# 3760/3760 [==============================] - 1s 379us/step - loss: 5.5896 - mean_absolute_percentage_error: 9.6767 - val_loss: 9.2097 - val_mean_absolute_percentage_error: 11.5963
# Training loss: 3.541460463250604, mape: 7.421252436699753
#
# Epoch 64/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 5.3580 - mean_absolute_percentage_error: 9.3944 - val_loss: 12.8169 - val_mean_absolute_percentage_error: 15.1332
# Training loss: 5.230346187939671, mape: 10.35585259082748
#
# Epoch 65/2000
# 3760/3760 [==============================] - 1s 363us/step - loss: 5.0398 - mean_absolute_percentage_error: 9.2559 - val_loss: 9.3324 - val_mean_absolute_percentage_error: 9.9652
# Training loss: 3.6763452969315558, mape: 6.34939283960501
#
# Epoch 66/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 5.4721 - mean_absolute_percentage_error: 9.4244 - val_loss: 8.6115 - val_mean_absolute_percentage_error: 10.8386
# Training loss: 3.050260239118111, mape: 6.471425952923549
#
# Epoch 67/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 5.2700 - mean_absolute_percentage_error: 9.4505 - val_loss: 12.4042 - val_mean_absolute_percentage_error: 14.5596
# Training loss: 5.44246874462161, mape: 10.241953368796564
#
# Epoch 68/2000
# 3760/3760 [==============================] - 1s 364us/step - loss: 5.2616 - mean_absolute_percentage_error: 9.4280 - val_loss: 9.0011 - val_mean_absolute_percentage_error: 10.0920
# Training loss: 3.4038944694747877, mape: 6.239446806770719
#
# Epoch 69/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 4.9488 - mean_absolute_percentage_error: 9.1009 - val_loss: 9.7827 - val_mean_absolute_percentage_error: 11.7549
# Training loss: 3.4741103418379025, mape: 7.097148495211395
#
# Epoch 70/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 5.4327 - mean_absolute_percentage_error: 9.5178 - val_loss: 9.9180 - val_mean_absolute_percentage_error: 10.1204
# Training loss: 3.614166668744017, mape: 6.1506968143011145
#
# Epoch 71/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 5.3226 - mean_absolute_percentage_error: 9.2928 - val_loss: 11.4467 - val_mean_absolute_percentage_error: 13.8577
# Training loss: 4.737432372339278, mape: 9.124925354951698
#
# Epoch 72/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 5.2043 - mean_absolute_percentage_error: 9.3977 - val_loss: 8.7232 - val_mean_absolute_percentage_error: 10.5617
# Training loss: 2.967673223593265, mape: 6.1358258609086045
#
# Epoch 73/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 5.1213 - mean_absolute_percentage_error: 9.1449 - val_loss: 11.0331 - val_mean_absolute_percentage_error: 9.7835
# Training loss: 4.351985848627048, mape: 6.210801298023411
#
# Epoch 74/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 5.2463 - mean_absolute_percentage_error: 9.3261 - val_loss: 10.1813 - val_mean_absolute_percentage_error: 9.9430
# Training loss: 3.9752414125606017, mape: 6.470908479217873
#
# Epoch 75/2000
# 3760/3760 [==============================] - 1s 364us/step - loss: 5.2659 - mean_absolute_percentage_error: 9.2951 - val_loss: 8.6902 - val_mean_absolute_percentage_error: 10.3171
# Training loss: 3.0187533609260018, mape: 6.3028426532465405
#
# Epoch 76/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 5.0910 - mean_absolute_percentage_error: 9.1575 - val_loss: 9.5661 - val_mean_absolute_percentage_error: 10.3688
# Training loss: 3.793103092910127, mape: 6.858194484682292
#
# Epoch 77/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 5.1574 - mean_absolute_percentage_error: 9.3584 - val_loss: 9.0812 - val_mean_absolute_percentage_error: 9.7655
# Training loss: 3.135051597054779, mape: 5.81558856262194
#
# Epoch 78/2000
# 3760/3760 [==============================] - 1s 364us/step - loss: 5.0016 - mean_absolute_percentage_error: 9.0288 - val_loss: 8.8636 - val_mean_absolute_percentage_error: 10.9149
# Training loss: 3.036485871617476, mape: 6.186186525320099
#
# Epoch 79/2000
# 3760/3760 [==============================] - 1s 363us/step - loss: 4.7895 - mean_absolute_percentage_error: 8.8932 - val_loss: 8.3596 - val_mean_absolute_percentage_error: 9.8520
# Training loss: 2.833561739245011, mape: 5.672623383392808
#
# Epoch 80/2000
# 3760/3760 [==============================] - 1s 357us/step - loss: 4.8754 - mean_absolute_percentage_error: 8.8716 - val_loss: 8.7574 - val_mean_absolute_percentage_error: 10.1199
# Training loss: 2.820111754295091, mape: 5.688467380772801
#
# Epoch 81/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 4.7140 - mean_absolute_percentage_error: 8.6394 - val_loss: 8.4641 - val_mean_absolute_percentage_error: 10.0443
# Training loss: 2.680364276875437, mape: 5.546890440557237
#
# Epoch 82/2000
# 3760/3760 [==============================] - 1s 363us/step - loss: 4.8948 - mean_absolute_percentage_error: 9.0219 - val_loss: 8.2460 - val_mean_absolute_percentage_error: 9.5575
# Training loss: 2.651059244014283, mape: 5.330684791699644
#
# Epoch 83/2000
# 3760/3760 [==============================] - 1s 365us/step - loss: 4.5163 - mean_absolute_percentage_error: 8.5580 - val_loss: 8.5360 - val_mean_absolute_percentage_error: 9.3713
# Training loss: 2.90890274664565, mape: 5.50690586469042
#
# Epoch 84/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 4.6306 - mean_absolute_percentage_error: 8.8321 - val_loss: 11.3328 - val_mean_absolute_percentage_error: 13.0120
# Training loss: 4.045226620704766, mape: 7.890563390326485
#
# Epoch 85/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 4.7968 - mean_absolute_percentage_error: 9.0022 - val_loss: 9.1562 - val_mean_absolute_percentage_error: 10.4284
# Training loss: 2.942246521262254, mape: 6.07027960361204
#
# Epoch 86/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 4.9589 - mean_absolute_percentage_error: 8.8956 - val_loss: 7.9236 - val_mean_absolute_percentage_error: 9.4324
# Training loss: 2.5921635922917, mape: 5.425091610997566
#
# Epoch 87/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 4.7609 - mean_absolute_percentage_error: 8.9905 - val_loss: 7.7345 - val_mean_absolute_percentage_error: 9.7684
# Training loss: 2.5949894426934543, mape: 5.592548726594491
#
# Epoch 88/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 4.8034 - mean_absolute_percentage_error: 9.0036 - val_loss: 10.6881 - val_mean_absolute_percentage_error: 9.6293
# Training loss: 4.083242332800935, mape: 5.962633928170333
#
# Epoch 89/2000
# 3760/3760 [==============================] - 1s 379us/step - loss: 4.7078 - mean_absolute_percentage_error: 8.8158 - val_loss: 7.9065 - val_mean_absolute_percentage_error: 9.7826
# Training loss: 2.486054405459088, mape: 5.39789351654215
#
# Epoch 90/2000
# 3760/3760 [==============================] - 1s 381us/step - loss: 4.6621 - mean_absolute_percentage_error: 8.9795 - val_loss: 9.1427 - val_mean_absolute_percentage_error: 9.4579
# Training loss: 3.1749904919015526, mape: 5.610952569636556
#
# Epoch 91/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 4.6220 - mean_absolute_percentage_error: 8.5753 - val_loss: 9.1610 - val_mean_absolute_percentage_error: 9.6201
# Training loss: 3.140634056761579, mape: 5.844592286941473
#
# Epoch 92/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 4.5550 - mean_absolute_percentage_error: 8.7136 - val_loss: 7.8470 - val_mean_absolute_percentage_error: 9.8330
# Training loss: 2.437724790429085, mape: 5.357195856012808
#
# Epoch 93/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 4.4088 - mean_absolute_percentage_error: 8.4856 - val_loss: 11.7163 - val_mean_absolute_percentage_error: 14.0595
# Training loss: 4.332463467128732, mape: 9.190431319356243
#
# Epoch 94/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 4.2553 - mean_absolute_percentage_error: 8.4604 - val_loss: 11.1126 - val_mean_absolute_percentage_error: 13.0410
# Training loss: 4.293996273723214, mape: 8.576706413004505
#
# Epoch 95/2000
# 3760/3760 [==============================] - 1s 382us/step - loss: 4.7648 - mean_absolute_percentage_error: 8.8878 - val_loss: 7.8375 - val_mean_absolute_percentage_error: 9.5661
# Training loss: 2.4127850165343796, mape: 5.173565101988695
#
# Epoch 96/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 4.5886 - mean_absolute_percentage_error: 8.5356 - val_loss: 8.8832 - val_mean_absolute_percentage_error: 9.4155
# Training loss: 3.2219540973948155, mape: 5.709094924131522
#
# Epoch 97/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 4.5854 - mean_absolute_percentage_error: 8.6411 - val_loss: 8.2105 - val_mean_absolute_percentage_error: 10.8145
# Training loss: 2.56982838907183, mape: 6.0085444674545645
#
# Epoch 98/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 4.2188 - mean_absolute_percentage_error: 8.2299 - val_loss: 8.1596 - val_mean_absolute_percentage_error: 10.0563
# Training loss: 2.4309137513145087, mape: 5.363090156063428
#
# Epoch 99/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 4.4304 - mean_absolute_percentage_error: 8.4947 - val_loss: 7.7557 - val_mean_absolute_percentage_error: 9.2312
# Training loss: 2.4072978026408944, mape: 5.072790476951769
#
# Epoch 100/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 4.1926 - mean_absolute_percentage_error: 8.3718 - val_loss: 8.3829 - val_mean_absolute_percentage_error: 9.9860
# Training loss: 2.50253873174684, mape: 5.309513447462714
#
# Epoch 101/2000
# 3760/3760 [==============================] - 1s 377us/step - loss: 4.4621 - mean_absolute_percentage_error: 8.6438 - val_loss: 7.6104 - val_mean_absolute_percentage_error: 9.2025
# Training loss: 2.3950313289376983, mape: 5.104153332672736
#
# Epoch 102/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 4.3499 - mean_absolute_percentage_error: 8.4226 - val_loss: 7.9433 - val_mean_absolute_percentage_error: 9.1717
# Training loss: 2.52295206070352, mape: 5.169642158123667
#
# Epoch 103/2000
# 3760/3760 [==============================] - 1s 381us/step - loss: 4.2940 - mean_absolute_percentage_error: 8.5387 - val_loss: 7.6470 - val_mean_absolute_percentage_error: 9.4847
# Training loss: 2.2811244781208506, mape: 5.099092980542859
#
# Epoch 104/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 4.3137 - mean_absolute_percentage_error: 8.4572 - val_loss: 7.9417 - val_mean_absolute_percentage_error: 9.2056
# Training loss: 2.3865541996942685, mape: 4.896372212270198
#
# Epoch 105/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 4.1226 - mean_absolute_percentage_error: 8.1561 - val_loss: 8.2480 - val_mean_absolute_percentage_error: 10.1719
# Training loss: 2.52343549852142, mape: 5.6644253956969814
#
# Epoch 106/2000
# 3760/3760 [==============================] - 1s 381us/step - loss: 4.2985 - mean_absolute_percentage_error: 8.5165 - val_loss: 8.2159 - val_mean_absolute_percentage_error: 9.1194
# Training loss: 2.6669759805140103, mape: 5.049340202057268
#
# Epoch 107/2000
# 3760/3760 [==============================] - 1s 375us/step - loss: 4.3550 - mean_absolute_percentage_error: 8.3314 - val_loss: 8.2654 - val_mean_absolute_percentage_error: 10.3091
# Training loss: 2.5048779532443306, mape: 5.698805403085598
#
# Epoch 108/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 4.3532 - mean_absolute_percentage_error: 8.5783 - val_loss: 8.3249 - val_mean_absolute_percentage_error: 9.2281
# Training loss: 2.794340315029434, mape: 5.23658743434144
#
# Epoch 109/2000
# 3760/3760 [==============================] - 1s 377us/step - loss: 4.1716 - mean_absolute_percentage_error: 8.3893 - val_loss: 8.1734 - val_mean_absolute_percentage_error: 9.8152
# Training loss: 2.441093062218441, mape: 5.300950857153143
#
# Epoch 110/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 4.1162 - mean_absolute_percentage_error: 8.1222 - val_loss: 7.4348 - val_mean_absolute_percentage_error: 9.1459
# Training loss: 2.1749460725068186, mape: 4.772351132076209
#
# Epoch 111/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 4.3116 - mean_absolute_percentage_error: 8.3790 - val_loss: 8.5099 - val_mean_absolute_percentage_error: 10.5050
# Training loss: 2.4459496827562726, mape: 5.357759005464003
#
# Epoch 112/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 4.1358 - mean_absolute_percentage_error: 8.3092 - val_loss: 7.3920 - val_mean_absolute_percentage_error: 9.4175
# Training loss: 2.240574290817835, mape: 5.237733624281211
#
# Epoch 113/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 4.1893 - mean_absolute_percentage_error: 8.3603 - val_loss: 7.4106 - val_mean_absolute_percentage_error: 9.1688
# Training loss: 2.183332186408612, mape: 4.803139050192996
#
# Epoch 114/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 4.2172 - mean_absolute_percentage_error: 8.3218 - val_loss: 7.7185 - val_mean_absolute_percentage_error: 9.4459
# Training loss: 2.334900457791586, mape: 4.995603361780962
#
# Epoch 115/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 4.3166 - mean_absolute_percentage_error: 8.2492 - val_loss: 8.6960 - val_mean_absolute_percentage_error: 10.6515
# Training loss: 2.539071048784449, mape: 5.463531949372526
#
# Epoch 116/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 4.4032 - mean_absolute_percentage_error: 8.4343 - val_loss: 8.3148 - val_mean_absolute_percentage_error: 10.9725
# Training loss: 2.6044641838406433, mape: 6.340179848686175
#
# Epoch 117/2000
# 3760/3760 [==============================] - 1s 377us/step - loss: 4.2010 - mean_absolute_percentage_error: 8.4334 - val_loss: 8.2282 - val_mean_absolute_percentage_error: 8.9689
# Training loss: 2.6904449517664517, mape: 5.0808098948628215
#
# Epoch 118/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 4.1444 - mean_absolute_percentage_error: 8.2383 - val_loss: 7.2023 - val_mean_absolute_percentage_error: 8.7813
# Training loss: 2.141357960079204, mape: 4.705945205850769
#
# Epoch 119/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 4.1603 - mean_absolute_percentage_error: 8.2815 - val_loss: 8.0684 - val_mean_absolute_percentage_error: 9.1287
# Training loss: 2.279768344316805, mape: 4.674951899434577
#
# Epoch 120/2000
# 3760/3760 [==============================] - 1s 377us/step - loss: 4.0766 - mean_absolute_percentage_error: 8.1844 - val_loss: 7.6617 - val_mean_absolute_percentage_error: 9.5886
# Training loss: 2.2031056769881645, mape: 4.912386106496363
#
# Epoch 121/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 4.0708 - mean_absolute_percentage_error: 8.3114 - val_loss: 7.5921 - val_mean_absolute_percentage_error: 8.9098
# Training loss: 2.2750660117903405, mape: 4.951053289929949
#
# Epoch 122/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 4.1356 - mean_absolute_percentage_error: 8.2678 - val_loss: 7.2558 - val_mean_absolute_percentage_error: 8.5773
# Training loss: 2.137787548690825, mape: 4.466024136294763
#
# Epoch 123/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 4.3961 - mean_absolute_percentage_error: 8.3537 - val_loss: 7.9083 - val_mean_absolute_percentage_error: 9.6821
# Training loss: 2.245117358516262, mape: 5.003538290355287
#
# Epoch 124/2000
# 3760/3760 [==============================] - 1s 375us/step - loss: 4.2282 - mean_absolute_percentage_error: 8.3542 - val_loss: 7.7336 - val_mean_absolute_percentage_error: 9.2883
# Training loss: 2.304392570790979, mape: 4.979897828336422
#
# Epoch 125/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 4.0442 - mean_absolute_percentage_error: 7.9836 - val_loss: 7.2019 - val_mean_absolute_percentage_error: 8.8339
# Training loss: 2.054805843152028, mape: 4.565455051463504
#
# Epoch 126/2000
# 3760/3760 [==============================] - 1s 378us/step - loss: 3.9725 - mean_absolute_percentage_error: 8.1639 - val_loss: 7.3502 - val_mean_absolute_percentage_error: 9.0593
# Training loss: 2.082085317714345, mape: 4.591353055543784
#
# Epoch 127/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 3.9853 - mean_absolute_percentage_error: 8.1256 - val_loss: 7.3716 - val_mean_absolute_percentage_error: 9.2337
# Training loss: 2.0990794868931775, mape: 4.639192803518186
#
# Epoch 128/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 3.9483 - mean_absolute_percentage_error: 7.8101 - val_loss: 9.0268 - val_mean_absolute_percentage_error: 10.9309
# Training loss: 2.5894675671711953, mape: 5.906001732263685
#
# Epoch 129/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 4.0633 - mean_absolute_percentage_error: 8.1662 - val_loss: 7.5925 - val_mean_absolute_percentage_error: 8.3692
# Training loss: 2.3034658642987753, mape: 4.422722227952248
#
# Epoch 130/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 3.9350 - mean_absolute_percentage_error: 7.8262 - val_loss: 8.4522 - val_mean_absolute_percentage_error: 10.2188
# Training loss: 2.45342657916522, mape: 5.179072409075794
#
# Epoch 131/2000
# 3760/3760 [==============================] - 1s 378us/step - loss: 3.9080 - mean_absolute_percentage_error: 7.9414 - val_loss: 7.4037 - val_mean_absolute_percentage_error: 9.0493
# Training loss: 2.1797405493256896, mape: 4.627142264522965
#
# Epoch 132/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 3.9563 - mean_absolute_percentage_error: 7.8509 - val_loss: 7.4651 - val_mean_absolute_percentage_error: 9.3472
# Training loss: 2.1022832718739433, mape: 4.7119942210476795
#
# Epoch 133/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 4.0557 - mean_absolute_percentage_error: 8.0613 - val_loss: 7.7975 - val_mean_absolute_percentage_error: 8.8405
# Training loss: 2.666941535647842, mape: 5.22336817832481
#
# Epoch 134/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 4.1406 - mean_absolute_percentage_error: 8.0353 - val_loss: 8.3513 - val_mean_absolute_percentage_error: 10.5706
# Training loss: 2.437149873517265, mape: 5.370868006505197
#
# Epoch 135/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 4.1958 - mean_absolute_percentage_error: 8.1191 - val_loss: 6.9847 - val_mean_absolute_percentage_error: 8.9923
# Training loss: 1.9346508639996367, mape: 4.40853954340341
#
# Epoch 136/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 4.0331 - mean_absolute_percentage_error: 8.1234 - val_loss: 8.2935 - val_mean_absolute_percentage_error: 10.6154
# Training loss: 2.4884924475777987, mape: 5.577334252044866
#
# Epoch 137/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 3.9600 - mean_absolute_percentage_error: 7.7271 - val_loss: 10.3453 - val_mean_absolute_percentage_error: 12.2881
# Training loss: 3.549096092876539, mape: 7.04889655544311
#
# Epoch 138/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 3.8171 - mean_absolute_percentage_error: 7.8412 - val_loss: 8.8149 - val_mean_absolute_percentage_error: 9.0721
# Training loss: 2.7693278435011464, mape: 4.898901023856632
#
# Epoch 139/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 3.9315 - mean_absolute_percentage_error: 7.8110 - val_loss: 7.9225 - val_mean_absolute_percentage_error: 9.9415
# Training loss: 2.1605537531604617, mape: 4.9738438875465745
#
# Epoch 140/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 3.9742 - mean_absolute_percentage_error: 8.0920 - val_loss: 7.5868 - val_mean_absolute_percentage_error: 8.9357
# Training loss: 2.400478740165498, mape: 5.0542971775953225
#
# Epoch 141/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 3.9090 - mean_absolute_percentage_error: 7.8411 - val_loss: 12.3738 - val_mean_absolute_percentage_error: 13.7035
# Training loss: 4.274236108211476, mape: 8.401992091065491
#
# Epoch 142/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 3.8013 - mean_absolute_percentage_error: 7.9584 - val_loss: 7.3595 - val_mean_absolute_percentage_error: 9.2708
# Training loss: 2.116173244542047, mape: 4.768859165015562
#
# Epoch 143/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 3.9041 - mean_absolute_percentage_error: 7.8903 - val_loss: 7.2785 - val_mean_absolute_percentage_error: 9.0934
# Training loss: 2.099677622863471, mape: 4.513624828689988
#
# Epoch 144/2000
# 3760/3760 [==============================] - 1s 373us/step - loss: 3.9768 - mean_absolute_percentage_error: 8.0973 - val_loss: 7.3558 - val_mean_absolute_percentage_error: 8.9796
# Training loss: 2.0114307450223694, mape: 4.499442200943704
#
# Epoch 145/2000
# 3760/3760 [==============================] - 1s 365us/step - loss: 3.9216 - mean_absolute_percentage_error: 7.8264 - val_loss: 9.6341 - val_mean_absolute_percentage_error: 9.2686
# Training loss: 3.114541658313445, mape: 5.028118209822638
#
# Epoch 146/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 4.0103 - mean_absolute_percentage_error: 8.0115 - val_loss: 8.4372 - val_mean_absolute_percentage_error: 9.0315
# Training loss: 2.5438291585792814, mape: 4.702257733729463
#
# Epoch 147/2000
# 3760/3760 [==============================] - 1s 365us/step - loss: 3.9667 - mean_absolute_percentage_error: 7.8582 - val_loss: 9.4675 - val_mean_absolute_percentage_error: 9.2298
# Training loss: 3.3486052711728633, mape: 5.89570887487915
#
# Epoch 148/2000
# 3760/3760 [==============================] - 1s 365us/step - loss: 3.9543 - mean_absolute_percentage_error: 7.9378 - val_loss: 7.1351 - val_mean_absolute_percentage_error: 8.9152
# Training loss: 2.068350344813902, mape: 4.6066936824809135
#
# Epoch 149/2000
# 3760/3760 [==============================] - 1s 385us/step - loss: 4.0564 - mean_absolute_percentage_error: 8.0801 - val_loss: 7.7674 - val_mean_absolute_percentage_error: 9.5051
# Training loss: 2.1718560537108207, mape: 4.6034793099097255
#
# Epoch 150/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 3.9859 - mean_absolute_percentage_error: 7.8340 - val_loss: 8.2594 - val_mean_absolute_percentage_error: 9.9419
# Training loss: 2.2792564374643347, mape: 5.03887142553859
#
# Epoch 151/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 3.9669 - mean_absolute_percentage_error: 7.7826 - val_loss: 8.1155 - val_mean_absolute_percentage_error: 9.1939
# Training loss: 2.3526871404706657, mape: 5.127961189385248
#
# Epoch 152/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 3.9049 - mean_absolute_percentage_error: 7.9148 - val_loss: 8.2215 - val_mean_absolute_percentage_error: 9.2625
# Training loss: 2.203829002644097, mape: 4.442199883524902
#
# Epoch 153/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 3.7830 - mean_absolute_percentage_error: 7.7906 - val_loss: 8.6466 - val_mean_absolute_percentage_error: 10.6465
# Training loss: 2.403037259386489, mape: 5.322983118757951
#
# Epoch 154/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 3.7617 - mean_absolute_percentage_error: 7.7018 - val_loss: 8.3436 - val_mean_absolute_percentage_error: 10.7250
# Training loss: 2.4365644361637573, mape: 5.836951279127961
#
# Epoch 155/2000
# 3760/3760 [==============================] - 1s 367us/step - loss: 3.6566 - mean_absolute_percentage_error: 7.7508 - val_loss: 7.3618 - val_mean_absolute_percentage_error: 8.6305
# Training loss: 2.08250663565007, mape: 4.371640040047294
#
# Epoch 156/2000
# 3760/3760 [==============================] - 1s 362us/step - loss: 3.9435 - mean_absolute_percentage_error: 7.8322 - val_loss: 7.3668 - val_mean_absolute_percentage_error: 9.2964
# Training loss: 1.9930862821535567, mape: 4.367405324812976
#
# Epoch 157/2000
# 3760/3760 [==============================] - 1s 372us/step - loss: 3.9039 - mean_absolute_percentage_error: 7.8485 - val_loss: 7.5334 - val_mean_absolute_percentage_error: 9.3469
# Training loss: 2.0201445047816327, mape: 4.556058995243438
#
# Epoch 158/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 3.7740 - mean_absolute_percentage_error: 7.8554 - val_loss: 7.2206 - val_mean_absolute_percentage_error: 9.0235
# Training loss: 1.9206426680734678, mape: 4.305852360127962
#
# Epoch 159/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 3.6924 - mean_absolute_percentage_error: 7.7579 - val_loss: 8.1842 - val_mean_absolute_percentage_error: 9.6917
# Training loss: 2.204609313637012, mape: 4.709216998501347
#
# Epoch 160/2000
# 3760/3760 [==============================] - 1s 382us/step - loss: 3.8889 - mean_absolute_percentage_error: 7.8192 - val_loss: 8.6714 - val_mean_absolute_percentage_error: 9.2607
# Training loss: 2.8622546377549196, mape: 5.352603223825409
#
# Epoch 161/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 3.7659 - mean_absolute_percentage_error: 7.6715 - val_loss: 7.4826 - val_mean_absolute_percentage_error: 8.8494
# Training loss: 2.0135413046923882, mape: 4.191504039654856
#
# Epoch 162/2000
# 3760/3760 [==============================] - 1s 377us/step - loss: 3.6100 - mean_absolute_percentage_error: 7.6573 - val_loss: 7.2711 - val_mean_absolute_percentage_error: 8.6539
# Training loss: 1.891395574629345, mape: 3.915262316825719
#
# Epoch 163/2000
# 3760/3760 [==============================] - 1s 375us/step - loss: 3.6034 - mean_absolute_percentage_error: 7.4713 - val_loss: 7.2183 - val_mean_absolute_percentage_error: 8.6961
# Training loss: 1.8238230713173016, mape: 3.8056177452913476
#
# Epoch 164/2000
# 3760/3760 [==============================] - 1s 385us/step - loss: 3.6408 - mean_absolute_percentage_error: 7.3830 - val_loss: 7.0658 - val_mean_absolute_percentage_error: 8.5965
# Training loss: 1.778438513544209, mape: 3.6923806499456044
#
# Epoch 165/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 3.7463 - mean_absolute_percentage_error: 7.5325 - val_loss: 7.1384 - val_mean_absolute_percentage_error: 8.7855
# Training loss: 1.774337766728891, mape: 3.734785172463072
#
# Epoch 166/2000
# 3760/3760 [==============================] - 1s 360us/step - loss: 3.5300 - mean_absolute_percentage_error: 7.2472 - val_loss: 7.0597 - val_mean_absolute_percentage_error: 8.6218
# Training loss: 1.7540891315043923, mape: 3.61879928546671
#
# Epoch 167/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 3.6018 - mean_absolute_percentage_error: 7.5624 - val_loss: 7.2452 - val_mean_absolute_percentage_error: 8.8445
# Training loss: 1.7865519827920004, mape: 3.701994367874168
#
# Epoch 168/2000
# 3760/3760 [==============================] - 1s 378us/step - loss: 3.5244 - mean_absolute_percentage_error: 7.2944 - val_loss: 7.1269 - val_mean_absolute_percentage_error: 8.5644
# Training loss: 1.7730234301209424, mape: 3.5824702570626545
#
# Epoch 169/2000
# 3760/3760 [==============================] - 1s 377us/step - loss: 3.4186 - mean_absolute_percentage_error: 7.2055 - val_loss: 7.1780 - val_mean_absolute_percentage_error: 8.6271
# Training loss: 1.7617473963396875, mape: 3.5484288091280187
#
# Epoch 170/2000
# 3760/3760 [==============================] - 1s 364us/step - loss: 3.5373 - mean_absolute_percentage_error: 7.3766 - val_loss: 7.2472 - val_mean_absolute_percentage_error: 8.8016
# Training loss: 1.7698012202680173, mape: 3.6024614361290523
#
# Epoch 171/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 3.4691 - mean_absolute_percentage_error: 7.2053 - val_loss: 7.2199 - val_mean_absolute_percentage_error: 8.5516
# Training loss: 1.7673680769638973, mape: 3.510055712399851
#
# Epoch 172/2000
# 3760/3760 [==============================] - 1s 371us/step - loss: 3.5639 - mean_absolute_percentage_error: 7.2881 - val_loss: 7.2045 - val_mean_absolute_percentage_error: 8.6198
# Training loss: 1.7576331056652867, mape: 3.529070406461163
#
# Epoch 173/2000
# 3760/3760 [==============================] - 1s 368us/step - loss: 3.5647 - mean_absolute_percentage_error: 7.2616 - val_loss: 7.1381 - val_mean_absolute_percentage_error: 8.5649
# Training loss: 1.749166430729142, mape: 3.525788190136106
#
# Epoch 174/2000
# 3760/3760 [==============================] - 1s 370us/step - loss: 3.7018 - mean_absolute_percentage_error: 7.3453 - val_loss: 7.2526 - val_mean_absolute_percentage_error: 8.5933
# Training loss: 1.7613762065568546, mape: 3.516370062066301
#
# Epoch 175/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 3.4836 - mean_absolute_percentage_error: 7.3387 - val_loss: 7.3241 - val_mean_absolute_percentage_error: 8.8536
# Training loss: 1.7698714568294938, mape: 3.625202168811765
#
# Epoch 176/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 3.3354 - mean_absolute_percentage_error: 7.2410 - val_loss: 7.1613 - val_mean_absolute_percentage_error: 8.7393
# Training loss: 1.7406932216734359, mape: 3.56934063263686
#
# Epoch 177/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 3.6227 - mean_absolute_percentage_error: 7.3553 - val_loss: 7.2003 - val_mean_absolute_percentage_error: 8.7979
# Training loss: 1.7473098321357603, mape: 3.6163304776644307
#
# Epoch 178/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 3.3802 - mean_absolute_percentage_error: 7.2096 - val_loss: 7.4226 - val_mean_absolute_percentage_error: 8.9752
# Training loss: 1.7998993087895143, mape: 3.7411558913616543
#
# Epoch 179/2000
# 3760/3760 [==============================] - 1s 369us/step - loss: 3.4898 - mean_absolute_percentage_error: 7.4202 - val_loss: 7.3980 - val_mean_absolute_percentage_error: 8.9558
# Training loss: 1.7888942425161238, mape: 3.6738715286433403
#
# Epoch 180/2000
# 3760/3760 [==============================] - 1s 374us/step - loss: 3.4817 - mean_absolute_percentage_error: 7.3833 - val_loss: 7.3180 - val_mean_absolute_percentage_error: 8.9035
# Training loss: 1.7653725854743416, mape: 3.602526741214469
#
# Epoch 181/2000
# 3760/3760 [==============================] - 1s 375us/step - loss: 3.7019 - mean_absolute_percentage_error: 7.4383 - val_loss: 7.4859 - val_mean_absolute_percentage_error: 9.1337
# Training loss: 1.8120882706397696, mape: 3.779359832922719
#
# Epoch 182/2000
# 3760/3760 [==============================] - 1s 381us/step - loss: 3.6652 - mean_absolute_percentage_error: 7.5120 - val_loss: 7.2170 - val_mean_absolute_percentage_error: 8.7376
# Training loss: 1.7318249539450568, mape: 3.4629399036504034
#
# Epoch 183/2000
# 3760/3760 [==============================] - 1s 378us/step - loss: 3.6549 - mean_absolute_percentage_error: 7.4026 - val_loss: 7.1081 - val_mean_absolute_percentage_error: 8.4873
# Training loss: 1.7227831955946042, mape: 3.4270532985769213
#
# Epoch 184/2000
# 3760/3760 [==============================] - 1s 375us/step - loss: 3.5424 - mean_absolute_percentage_error: 7.5102 - val_loss: 7.2430 - val_mean_absolute_percentage_error: 8.8747
# Training loss: 1.7362554685482698, mape: 3.531637527313265
#
# Epoch 185/2000
# 3760/3760 [==============================] - 1s 376us/step - loss: 3.5386 - mean_absolute_percentage_error: 7.3864 - val_loss: 7.2499 - val_mean_absolute_percentage_error: 8.8448
# Training loss: 1.740851997390906, mape: 3.4996900722793356
#
# 1000/1000 [==============================] - 0s 178us/step
# 4701/4701 [==============================] - 1s 143us/step
# Training mape: 4.40853954340341
# Test mape: 6.9266080513000485
# Training percent within 1km: 78.91937885556266
# Testing percent within 1km: 66.60000000000001

# %%
#diff = np.abs((y_pred*sigma_labels+mu)-(y_test*sigma_labels+mu))
diff = (np.transpose(predictions))-(y_test)
error = diff[diff>1]
percent_correct = (len(y_test)-len(error))/len(y_test)
print(percent_correct)
# Out:
# 0.8

# %%
model1 = keras.models.load_model('cnnr_model_bc.h5')
model1.summary()

predictions = model1.predict(X_test)
diff = abs((np.transpose(predictions))-(y_test))
error = diff[diff>1]
percent_correct = (len(y_test)-len(error))/len(y_test)


print('Test mape:', test_acc)
print('Testing percent within 1km:', percent_correct*100)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_35 (Conv2D)           (None, 32, 32, 16)        1584
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 16, 16, 32)        25120
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 8, 8, 64)          51264
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 2, 2, 256)         295168
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 711,633
# Trainable params: 710,641
# Non-trainable params: 992
# _________________________________________________________________
# Test mape: 7.635437088012695
# Testing percent within 1km: 57.8

# %%
epoch = np.arange(1,len(infdb.history['loss'])+1)
fig1 = plt.figure()
plt.subplot(1,2,1)
plt.suptitle('SNR = INF')
plt.plot(epoch, infdb.history['loss'], label = 'Training')
plt.plot(epoch, infdb.history['val_loss'],label = 'Testing')
plt.legend()
plt.grid()
plt.xlabel('Epoch Number')
plt.ylabel('MSE Loss')
plt.axis([1, 100, 0, 300])
plt.subplot(1,2,2)
plt.plot(epoch, np.array(infdb.history['mean_absolute_percentage_error']),label = 'Training')
plt.plot(epoch, np.array(infdb.history['val_mean_absolute_percentage_error']),label = 'Testing')
plt.legend()
plt.xlabel('Epoch Number')
plt.ylabel('MAPE')
plt.grid()
plt.axis([1, 100, 0, 100])
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
#sort output for plotting

inds = y_test.argsort()
sorted_y_test = y_test[inds]

sorted_y_pred = np.squeeze(predictions)[inds]

# %%
#Plotting
fig1 = plt.figure(figsize = (20,14))
plt.scatter(sorted_y_test,sorted_y_pred)
plt.axis([0, 50, 0, 50])
plt.ylabel('Predicted Distance (km)',fontsize=20)
plt.xlabel('Actual Distance (km)',fontsize=20)
plt.title('SNR = INF',fontsize=20)
plt.grid()
